# %%
# test_api.py
import requests

# 발급한 API_KEY
API_KEY = "23e1c43e06ebbf18f7886c1f70760514"
city_name = "Seoul"
# OpenWeatherMap API URL
url = f"https://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={API_KEY}"

# API에 GET 요청 보내기
response = requests.get(url)

# 응답 확인
if response.status_code == 200:
    weather_data = response.json()
    print("성공적으로 날씨 정보를 가져왔습니다.")
    print(weather_data)
else:
    print(f"오류가 발생했습니다. 상태 코드: {response.status_code}")
    print(response.text)
# Out:
# 성공적으로 날씨 정보를 가져왔습니다.
# {'coord': {'lon': 126.9778, 'lat': 37.5683}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 288.98, 'feels_like': 289.1, 'temp_min': 288.98, 'temp_max': 288.98, 'pressure': 1016, 'humidity': 95, 'sea_level': 1016, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 3.12, 'deg': 63, 'gust': 9.05}, 'rain': {'1h': 0.47}, 'clouds': {'all': 100}, 'dt': 1760354100, 'sys': {'country': 'KR', 'sunrise': 1760305072, 'sunset': 1760345915}, 'timezone': 32400, 'id': 1835848, 'name': 'Seoul', 'cod': 200}
